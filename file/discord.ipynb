# %%
import requests
import json

# %%
def discord_message(channel_id):
    headers={
        'authorization':''''''
    }
    response=requests.get(f"https://discord.com/api/v9/channels/{channel_id}/messages", headers=headers)
    jsson=json.loads(response.text)
#     print(jsson[0]['author'])
#     for value in jsson:
#         print(value,"\n")
    return jsson

# %%
discord_message('1116648231485583360')
# Out:
# [{'id': '1137341168208846978',
#   'type': 0,
#   'content': 'dividing into more small function',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-05T11:07:45.278000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1137340466052989009',
#   'type': 0,
#   'content': 'without __import__ ,there is file is create all code',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-05T11:04:57.871000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1137307559573848104',
#   'type': 0,
#   'content': 'manage code\nanalysis: call with open before assignment try to solve.\noutput: working on parameter',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-05T08:54:12.355000+00:00',
#   'edited_timestamp': '2023-08-05T10:22:47.009000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1137291552666947585',
#   'type': 0,
#   'content': 'code is organized but still use __import__ functions find another way to read code and print\nanalysis: use with open with r mode and use ast for print.\nouptut: can read and write the code with open function and ast liabrary to the solve using the chatgpt',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-05T07:50:36.011000+00:00',
#   'edited_timestamp': '2023-08-05T08:53:56.815000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136956372538368050',
#   'type': 0,
#   'content': 'debugging',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-04T09:38:42.841000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1136936297693462529',
#   'type': 0,
#   'content': 'outputfile,content',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-04T08:18:56.625000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1136925797194682408',
#   'type': 0,
#   'content': 'calling and manage code try to run',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-04T07:37:13.111000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1136917899739680788',
#   'type': 0,
#   'content': 'code manage in function',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-04T07:05:50.211000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1136606150599647277',
#   'type': 0,
#   'content': 'analysis:\n1.if sum of two number match then remove these number from list \nchallenges:\n1.have access those element from two list and match to day sales',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-03T10:27:03.424000+00:00',
#   'edited_timestamp': '2023-08-03T11:20:43.185000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136585418628935702',
#   'type': 0,
#   'content': 'try to solve exmaple of level 3 coding',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-03T09:04:40.537000+00:00',
#   'edited_timestamp': '2023-08-03T09:15:42.490000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136577156588257310',
#   'type': 0,
#   'content': 'sum two number and try to match number from day of sales',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-03T08:31:50.713000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1136568271819247617',
#   'type': 19,
#   'content': 'working as above approaches',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-03T07:56:32.419000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': [],
#   'message_reference': {'channel_id': '1116648231485583360',
#    'message_id': '1136559794304598026',
#    'guild_id': '1047208198286884926'},
#   'referenced_message': {'id': '1136559794304598026',
#    'type': 19,
#    'content': 'analysis coding strategy:\noutput:\n1.first there is two list sales and payment. may three is list.\n2. three loop are uses\n3.search the match number and print the remaning day',
#    'channel_id': '1116648231485583360',
#    'author': {'id': '1041271050203308055',
#     'username': 'bibhutimukhiya',
#     'avatar': None,
#     'discriminator': '0',
#     'public_flags': 0,
#     'flags': 0,
#     'banner': None,
#     'accent_color': None,
#     'global_name': 'bibhuti mukhiya',
#     'avatar_decoration_data': None,
#     'banner_color': None},
#    'attachments': [],
#    'embeds': [],
#    'mentions': [],
#    'mention_roles': [],
#    'pinned': False,
#    'mention_everyone': False,
#    'tts': False,
#    'timestamp': '2023-08-03T07:22:51.222000+00:00',
#    'edited_timestamp': '2023-08-03T07:40:53.076000+00:00',
#    'flags': 0,
#    'components': [],
#    'message_reference': {'channel_id': '1116648231485583360',
#     'message_id': '1136251931656978464',
#     'guild_id': '1047208198286884926'}}},
#  {'id': '1136559794304598026',
#   'type': 19,
#   'content': 'analysis coding strategy:\noutput:\n1.first there is two list sales and payment. may three is list.\n2. three loop are uses\n3.search the match number and print the remaning day',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-03T07:22:51.222000+00:00',
#   'edited_timestamp': '2023-08-03T07:40:53.076000+00:00',
#   'flags': 0,
#   'components': [],
#   'message_reference': {'channel_id': '1116648231485583360',
#    'message_id': '1136251931656978464',
#    'guild_id': '1047208198286884926'},
#   'referenced_message': {'id': '1136251931656978464',
#    'type': 0,
#    'content': 'processs\n1. two loop\n2. sum\n3.',
#    'channel_id': '1116648231485583360',
#    'author': {'id': '1041271050203308055',
#     'username': 'bibhutimukhiya',
#     'avatar': None,
#     'discriminator': '0',
#     'public_flags': 0,
#     'flags': 0,
#     'banner': None,
#     'accent_color': None,
#     'global_name': 'bibhuti mukhiya',
#     'avatar_decoration_data': None,
#     'banner_color': None},
#    'attachments': [],
#    'embeds': [],
#    'mentions': [],
#    'mention_roles': [],
#    'pinned': False,
#    'mention_everyone': False,
#    'tts': False,
#    'timestamp': '2023-08-02T10:59:31.047000+00:00',
#    'edited_timestamp': '2023-08-02T11:15:17.168000+00:00',
#    'flags': 0,
#    'components': []}},
#  {'id': '1136251931656978464',
#   'type': 0,
#   'content': 'processs\n1. two loop\n2. sum\n3.',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-02T10:59:31.047000+00:00',
#   'edited_timestamp': '2023-08-02T11:15:17.168000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136246491141382235',
#   'type': 0,
#   'content': 'doing coding with approaches 1',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-02T10:37:53.927000+00:00',
#   'edited_timestamp': '2023-08-02T10:38:28.119000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136237997055025274',
#   'type': 0,
#   'content': 'calculating in copy \napproaches \n1. tried to match answer by sum of two number and find the from which money he lunch means i want said that\nif there is total money payment that day do not mention.\ncalculating in copy: level 3 question 3 solve\noutput: approaches 1 work for question 3',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-02T10:04:08.779000+00:00',
#   'edited_timestamp': '2023-08-02T10:35:16.108000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136222342020870204',
#   'type': 0,
#   'content': 'find approaches to trackal the question 3 \nseparate the into two list salse and payment in code',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-02T09:01:56.328000+00:00',
#   'edited_timestamp': '2023-08-02T09:03:23.917000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136206827743363114',
#   'type': 0,
#   'content': 'find more approaches\nprocess\n1. remove sum amount which found in the day write the remaining day only',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-02T08:00:17.436000+00:00',
#   'edited_timestamp': '2023-08-02T09:08:47.730000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1136197405415571498',
#   'type': 0,
#   'content': 'level 3 question 3 bakery \nanalysis: tried to match answer by sum of two number and find the from which money he lunch\noutput: one match only and need  more analysis',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-08-02T07:22:50.978000+00:00',
#   'edited_timestamp': '2023-08-02T09:08:11.578000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1135137008717660201',
#   'type': 19,
#   'content': "2. removing global\noutput: some error trying solving like parameter\nNameError: name 'file_module' is not defined\nerror due to not put self.",
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-30T09:09:12.704000+00:00',
#   'edited_timestamp': '2023-07-30T10:51:34.475000+00:00',
#   'flags': 0,
#   'components': [],
#   'message_reference': {'channel_id': '1116648231485583360',
#    'message_id': '1135121846589722624',
#    'guild_id': '1047208198286884926'},
#   'referenced_message': {'id': '1135121846589722624',
#    'type': 0,
#    'content': 'to achieve by reorganizing code:\n1. Provide code and return output.py\n2. the file path  and return output.py\n3. arrange code in function\noutput: exploring sys.path\n1. store at collection of path and copy 0 index from the',
#    'channel_id': '1116648231485583360',
#    'author': {'id': '1041271050203308055',
#     'username': 'bibhutimukhiya',
#     'avatar': None,
#     'discriminator': '0',
#     'public_flags': 0,
#     'flags': 0,
#     'banner': None,
#     'accent_color': None,
#     'global_name': 'bibhuti mukhiya',
#     'avatar_decoration_data': None,
#     'banner_color': None},
#    'attachments': [],
#    'embeds': [],
#    'mentions': [],
#    'mention_roles': [],
#    'pinned': False,
#    'mention_everyone': False,
#    'tts': False,
#    'timestamp': '2023-07-30T08:08:57.771000+00:00',
#    'edited_timestamp': '2023-07-30T09:06:58.575000+00:00',
#    'flags': 0,
#    'components': []}},
#  {'id': '1135121846589722624',
#   'type': 0,
#   'content': 'to achieve by reorganizing code:\n1. Provide code and return output.py\n2. the file path  and return output.py\n3. arrange code in function\noutput: exploring sys.path\n1. store at collection of path and copy 0 index from the',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-30T08:08:57.771000+00:00',
#   'edited_timestamp': '2023-07-30T09:06:58.575000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1135105641178988626',
#   'type': 0,
#   'content': "organizing the code with def and parameter\noutput :`sys.path.insert(0, lib_path)` adds a custom library path to the start of Python's module search list, prioritizing it over default paths for module lookup.\n>>add the path file which we provide and placed at zero index.",
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-30T07:04:34.100000+00:00',
#   'edited_timestamp': '2023-07-30T07:58:44.099000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134796132518744204',
#   'type': 0,
#   'content': 're-organizing the code',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-29T10:34:41.485000+00:00',
#   'edited_timestamp': '2023-07-29T10:34:49.952000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134744209224642630',
#   'type': 0,
#   'content': 'test case of auto access function code\ntest by ....',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-29T07:08:22.007000+00:00',
#   'edited_timestamp': '2023-07-29T08:16:44.624000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134434623972196414',
#   'type': 0,
#   'content': 'find out: how to read all file and print all need code in one file by file path\nanalysis: \n1.loop\n2.os module',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-28T10:38:11.131000+00:00',
#   'edited_timestamp': '2023-07-28T10:42:43.673000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134412579821846588',
#   'type': 0,
#   'content': 'analysis: access from folder\noutput: os module for read file and folder',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-28T09:10:35.396000+00:00',
#   'edited_timestamp': '2023-07-28T10:33:05.367000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134408409718988821',
#   'type': 0,
#   'content': 'complete and upload at github',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-28T08:54:01.166000+00:00',
#   'edited_timestamp': '2023-07-28T08:55:00.077000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134398594972143737',
#   'type': 0,
#   'content': 'now find out not existing function \nanalysis: try to write in output file\noutput: using set and loop and (__import__ source code) print print the remaining part function',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-28T08:15:01.148000+00:00',
#   'edited_timestamp': '2023-07-28T08:32:54.875000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134389915283619862',
#   'type': 0,
#   'content': 'analysis:\n1. store the function of def  in set() \n2.access list\n3. search in output file there is access def is existing or not,\n4. if not then write or paste that def function\noutput: use set difference for find not existing def in output.py',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-28T07:40:31.749000+00:00',
#   'edited_timestamp': '2023-07-28T08:13:40.036000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134380907462139996',
#   'type': 0,
#   'content': 'trying to write only not existing def function in output.py',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-28T07:04:44.117000+00:00',
#   'edited_timestamp': '2023-07-28T07:36:55.782000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134077845090603109',
#   'type': 0,
#   'content': 'solving question 3 of level 3 in copy',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-27T11:00:28.417000+00:00',
#   'edited_timestamp': '2023-07-27T11:00:39.882000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134059998457106513',
#   'type': 0,
#   'content': 'analysis question level 3 another way\noutput: by addition two number of payment make number which is available in day and if there is not match for any number is answer \n>> this work for example and question 2',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-27T09:49:33.448000+00:00',
#   'edited_timestamp': '2023-07-27T10:03:22.749000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134043812306620517',
#   'type': 0,
#   'content': 'try to  level 3 question in copy\nquestion 1 answer is 1. how??\noutput: from which day eat lunch that is answer',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-27T08:45:14.369000+00:00',
#   'edited_timestamp': '2023-07-27T09:58:21.914000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134033772866719774',
#   'type': 0,
#   'content': 'analysis the level 3:\noutput: \n1.john use money for lunch\n2.he can be pay in 4 part in any day\n3. answer is in which day paid the first day revenue',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-27T08:05:20.780000+00:00',
#   'edited_timestamp': '2023-07-27T08:43:55.286000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1134025448263794689',
#   'type': 0,
#   'content': 'trying to  solve remaining 3th question of level 2\nanalysis: 8 58 85 . here is left 77  why??\noutput: while comparing the sales and payment, string is not converted into integer.\ndone',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-27T07:32:16.040000+00:00',
#   'edited_timestamp': '2023-07-27T08:04:12.618000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1133723571701698651',
#   'type': 0,
#   'content': 'level 1 and 2 code complete remaining 3th question of level 2',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-26T11:32:43.059000+00:00',
#   'edited_timestamp': '2023-07-26T11:34:02.333000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1133710250621554698',
#   'type': 0,
#   'content': 'process : how to compare and execute\noutput: compare both list sales and payment then print incomplete payment day',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-26T10:39:47.066000+00:00',
#   'edited_timestamp': '2023-07-26T11:00:27.095000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1133695897633562684',
#   'type': 0,
#   'content': '1.first make 2 list which salesday and payment \ncompare both and store in other list\ndone',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-26T09:42:45.047000+00:00',
#   'edited_timestamp': '2023-07-26T10:39:13.274000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1133682886944493708',
#   'type': 0,
#   'content': 'level 1 and level 2 coding\nprocess\n0.split day and payment \n1.first make 2 list which salesday and payment \n2. compare both and store in other list',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-26T08:51:03.057000+00:00',
#   'edited_timestamp': '2023-07-26T09:15:26.899000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1133680367669346415',
#   'type': 0,
#   'content': 'level 1 complete in copy',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-26T08:41:02.415000+00:00',
#   'edited_timestamp': '2023-07-26T08:41:25.268000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1133671823905673267',
#   'type': 0,
#   'content': 'solving level 1\nquestion 3 doing in copy\n2.seperated by space when write the day',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-26T08:07:05.423000+00:00',
#   'edited_timestamp': '2023-07-26T08:38:10.773000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1133660469605957653',
#   'type': 0,
#   'content': 'Bakery - Level 1\nanalysis : bakery level 1\noutput: \n1.enter the incomplete payment day',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-26T07:21:58.347000+00:00',
#   'edited_timestamp': '2023-07-26T08:37:42.840000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1132633444774584330',
#   'type': 0,
#   'content': 'file handling for append',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-23T11:20:56.546000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1132622293558906932',
#   'type': 0,
#   'content': 'create a list to store called in the def function\ndone',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-23T10:36:37.889000+00:00',
#   'edited_timestamp': '2023-07-23T11:20:15.274000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1132614106118098975',
#   'type': 0,
#   'content': 'try to read new file and print def function',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-23T10:04:05.851000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1132606241269624902',
#   'type': 19,
#   'content': 'arranging code',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-23T09:32:50.725000+00:00',
#   'edited_timestamp': '2023-07-23T10:02:49.576000+00:00',
#   'flags': 0,
#   'components': [],
#   'message_reference': {'channel_id': '1116648231485583360',
#    'message_id': '1132598173177761843',
#    'guild_id': '1047208198286884926'},
#   'referenced_message': {'id': '1132598173177761843',
#    'type': 0,
#    'content': 'compare called function of new_file and function found in module and try to print not exist function',
#    'channel_id': '1116648231485583360',
#    'author': {'id': '1041271050203308055',
#     'username': 'bibhutimukhiya',
#     'avatar': None,
#     'discriminator': '0',
#     'public_flags': 0,
#     'flags': 0,
#     'banner': None,
#     'accent_color': None,
#     'global_name': 'bibhuti mukhiya',
#     'avatar_decoration_data': None,
#     'banner_color': None},
#    'attachments': [],
#    'embeds': [],
#    'mentions': [],
#    'mention_roles': [],
#    'pinned': False,
#    'mention_everyone': False,
#    'tts': False,
#    'timestamp': '2023-07-23T09:00:47.142000+00:00',
#    'edited_timestamp': None,
#    'flags': 0,
#    'components': []}},
#  {'id': '1132598173177761843',
#   'type': 0,
#   'content': 'compare called function of new_file and function found in module and try to print not exist function',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-23T09:00:47.142000+00:00',
#   'edited_timestamp': None,
#   'flags': 0,
#   'components': []},
#  {'id': '1132574666410696796',
#   'type': 0,
#   'content': 'trying to print all def functions of new file\nprinted with ast.FunctionDef',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-23T07:27:22.692000+00:00',
#   'edited_timestamp': '2023-07-23T08:56:12.269000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1132566241375166535',
#   'type': 0,
#   'content': 'need to remove repeated def functions while running the code\ntrying to solve by using ast.FunctionDef',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-23T06:53:54.007000+00:00',
#   'edited_timestamp': '2023-07-23T07:13:15.217000+00:00',
#   'flags': 0,
#   'components': []},
#  {'id': '1132268981261185044',
#   'type': 0,
#   'content': 'need to remove repeated def function\nhalf complete',
#   'channel_id': '1116648231485583360',
#   'author': {'id': '1041271050203308055',
#    'username': 'bibhutimukhiya',
#    'avatar': None,
#    'discriminator': '0',
#    'public_flags': 0,
#    'flags': 0,
#    'banner': None,
#    'accent_color': None,
#    'global_name': 'bibhuti mukhiya',
#    'avatar_decoration_data': None,
#    'banner_color': None},
#   'attachments': [],
#   'embeds': [],
#   'mentions': [],
#   'mention_roles': [],
#   'pinned': False,
#   'mention_everyone': False,
#   'tts': False,
#   'timestamp': '2023-07-22T11:12:41.673000+00:00',
#   'edited_timestamp': '2023-07-22T11:17:13.161000+00:00',
#   'flags': 0,
#   'components': []}]
